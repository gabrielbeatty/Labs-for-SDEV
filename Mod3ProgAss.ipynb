# %% [markdown]
# Gabriel Beatty
# SDEV 220
# Module 3 Programming Assignment

# %% [markdown]
# 7.4

# %%
things = ["mozzerela", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzerela', 'cinderella', 'salmonella']

# %% [markdown]
# 7.5

# %%
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzerela', 'Cinderella', 'salmonella']

# %% [markdown]
# By using the "=" I changed the element in the list to the capitalized version in a persisting way.

# %%
7.6

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZERELA', 'Cinderella', 'salmonella']

# %%
7.7

# %%
things.remove("salmonella")
print("I guess we all get a Nobel, these days...wamp, wamp!")
print(things)
# Out:
# I guess we all get a Nobel, these days...wamp, wamp!
# ['MOZZERELA', 'Cinderella']

# %%
9.1

# %%
def good():
    return['Harry', 'Ron', 'Hermione']
print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
9.2

# %%
def get_odds():
    for number in range(10):
        if number % 2 != 0:
            yield number
count = 1
for odd in get_odds():
    if count == 3:
        print("The third odd number is:", odd)
        break
    count += 1
# Out:
# The third odd number is: 5
